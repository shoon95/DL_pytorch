# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %%
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        print(batch_idx)
        print(samples)
        x_train ,y_train = samples
        prediction = model(x_train)
        
        cost = F.mse_loss(prediction, y_train)
        
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()
        
        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch    0/20 Batch 1/3 Cost: 32344.386719
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    0/20 Batch 2/3 Cost: 10722.382812
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    0/20 Batch 3/3 Cost: 5551.770020
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    1/20 Batch 1/3 Cost: 725.422852
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    1/20 Batch 2/3 Cost: 279.445709
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    1/20 Batch 3/3 Cost: 73.427765
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    2/20 Batch 1/3 Cost: 18.764778
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    2/20 Batch 2/3 Cost: 13.035372
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    2/20 Batch 3/3 Cost: 2.890664
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    3/20 Batch 1/3 Cost: 1.572676
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch    3/20 Batch 2/3 Cost: 0.371565
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    3/20 Batch 3/3 Cost: 0.002685
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    4/20 Batch 1/3 Cost: 0.194237
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    4/20 Batch 2/3 Cost: 0.402049
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    4/20 Batch 3/3 Cost: 0.888344
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    5/20 Batch 1/3 Cost: 0.032304
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    5/20 Batch 2/3 Cost: 0.772376
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    5/20 Batch 3/3 Cost: 0.906267
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    6/20 Batch 1/3 Cost: 0.030663
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    6/20 Batch 2/3 Cost: 0.767317
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    6/20 Batch 3/3 Cost: 0.908884
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    7/20 Batch 1/3 Cost: 0.663502
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch    7/20 Batch 2/3 Cost: 0.326474
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    7/20 Batch 3/3 Cost: 0.404634
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch    8/20 Batch 1/3 Cost: 0.111721
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch    8/20 Batch 2/3 Cost: 0.665725
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    8/20 Batch 3/3 Cost: 0.030179
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch    9/20 Batch 1/3 Cost: 0.285162
# 1
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch    9/20 Batch 2/3 Cost: 0.215709
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    9/20 Batch 3/3 Cost: 0.888603
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   10/20 Batch 1/3 Cost: 0.223425
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   10/20 Batch 2/3 Cost: 0.307061
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   10/20 Batch 3/3 Cost: 1.365149
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   11/20 Batch 1/3 Cost: 0.184418
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   11/20 Batch 2/3 Cost: 0.258687
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   11/20 Batch 3/3 Cost: 0.981259
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   12/20 Batch 1/3 Cost: 0.656923
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   12/20 Batch 2/3 Cost: 0.047795
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   12/20 Batch 3/3 Cost: 0.703237
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   13/20 Batch 1/3 Cost: 0.198932
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   13/20 Batch 2/3 Cost: 0.740256
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   13/20 Batch 3/3 Cost: 0.078639
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   14/20 Batch 1/3 Cost: 0.420464
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   14/20 Batch 2/3 Cost: 0.000654
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   14/20 Batch 3/3 Cost: 0.902059
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   15/20 Batch 1/3 Cost: 0.769982
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   15/20 Batch 2/3 Cost: 0.102330
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   15/20 Batch 3/3 Cost: 0.069386
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   16/20 Batch 1/3 Cost: 0.374803
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   16/20 Batch 2/3 Cost: 0.703712
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   16/20 Batch 3/3 Cost: 0.098919
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   17/20 Batch 1/3 Cost: 0.344710
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   17/20 Batch 2/3 Cost: 0.529526
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   17/20 Batch 3/3 Cost: 0.016354
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   18/20 Batch 1/3 Cost: 0.401043
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   18/20 Batch 2/3 Cost: 0.478444
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   18/20 Batch 3/3 Cost: 0.335588
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   19/20 Batch 1/3 Cost: 0.660659
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   19/20 Batch 2/3 Cost: 0.103824
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   19/20 Batch 3/3 Cost: 0.036310
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   20/20 Batch 1/3 Cost: 0.659528
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   20/20 Batch 2/3 Cost: 0.017853
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   20/20 Batch 3/3 Cost: 0.246048
